# %%
import pandas

# %%
import pandas as pd

# %%
pd.read_html("https://www.moneycontrol.com/us-markets")
# Out:
# [   Name     Unnamed: 1   Price  Change  Change%
#  0  CSCO  Cisco Systems   48.65    3.23     7.11
#  1   WMT        Walmart   73.17    4.49     6.54
#  2  INTC          Intel   20.93    1.01     5.07
#  3   NKE           Nike   81.79    3.18     4.05
#  4  AMZN         Amazon  176.34    6.00     3.52,
#    Name    Unnamed: 1   Price  Change  Change%
#  0   VZ       Verizon   40.17   -0.76    -1.86
#  1   PG           P&G  167.31   -1.57    -0.93
#  2  MRK    Merck & Co  112.86   -0.83    -0.73
#  3  UNH  UnitedHealth  579.00   -1.20    -0.21
#  4   KO     Coca-Cola   68.57   -0.07    -0.10,
#                                Name                       Unnamed: 1  \
#  0  No stocks touching 52 week High  No stocks touching 52 week High
#
#                               Price                           Change  \
#  0  No stocks touching 52 week High  No stocks touching 52 week High
#
#                             Change%
#  0  No stocks touching 52 week High  ,
# ...

# %%
pd.read_excel('/Users/sharoonkk/Desktop/DA/PANDAS/pandas_docs/demo1.xlsx',index_col=[0],sheet_name='Sheet4')
# Out:
#    a   b   c   d message
# 0  1   2   3   4      hi
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
data=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
pd.read_html("https://www.basketball-reference.com/players/c/curryst01.html")
# Out:
# [  Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Per 36 Minutes  \
#                Season                Age                 Lg             FG
#  0            2024-25                 36                NBA            9.5
#
#                                     ...                                 \
#      FGA   3P   3PA   FT  FTA  ORB  ...  AST  STL  BLK  TOV   PF   PTS
#  0  20.9  5.0  12.4  4.4  4.8  0.6  ...  5.8  0.9  0.4  3.2  2.0  28.2
#
#    Shooting               Unnamed: 20_level_0
#         FG%    3P%    FT%               WS/48
#  0    0.452  0.401  0.914               0.158
#
#  [1 rows x 21 columns],
#       Season   Age   Tm   Lg  Pos    G   GS    MP    FG   FGA  ...  ORB  DRB  \
#  0   2009-10  21.0  GSW  NBA   PG   80   77  36.2   6.6  14.3  ...  0.6  3.9
#  1   2010-11  22.0  GSW  NBA   PG   74   74  33.6   6.8  14.2  ...  0.7  3.2
#  2   2011-12  23.0  GSW  NBA   PG   26   23  28.2   5.6  11.4  ...  0.6  2.8
# ...

# %%
b=pd.read_html("https://www.basketball-reference.com/players/c/curryst01.html")

# %%
b[5]
# Out:
#     Season   Age   Tm   Lg  Pos    G   GS    MP    FG   FGA  ...  DRB  TRB  \
# 0  2012-13  24.0  GSW  NBA   PG   12   12   497   102   235  ...   41   46
# 1  2013-14  25.0  GSW  NBA   PG    7    7   296    51   116  ...   21   25
# 2  2014-15  26.0  GSW  NBA   PG   21   21   826   200   439  ...   85  105
# 3  2015-16  27.0  GSW  NBA   PG   18   17   614   148   338  ...   85   99
# 4  2016-17  28.0  GSW  NBA   PG   17   17   601   151   312  ...   84  106
# 5  2017-18  29.0  GSW  NBA   PG   15   14   555   137   304  ...   82   91
# 6  2018-19  30.0  GSW  NBA   PG   22   22   846   190   431  ...  115  132
# 7  2021-22  33.0  GSW  NBA   PG   22   18   764   202   440  ...  104  115
# 8  2022-23  34.0  GSW  NBA   PG   13   13   493   145   311  ...   58   67
# 9   Career   NaN  NaN  NBA  NaN  147  141  5492  1326  2926  ...  675  786
#
#    AST  STL  BLK  TOV   PF   PTS  Unnamed: 30  Trp-Dbl
# 0   97   20    2   40   35   281          NaN        0
# ...

# %%
len(b)
# Out:
# 8

# %%
pd.read_csv('/Users/sharoonkk/Downloads/archive/train.csv')
# Out:
#       age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0      58;"management";"married";"tertiary";"no";2143...
# 1      44;"technician";"single";"secondary";"no";29;"...
# 2      33;"entrepreneur";"married";"secondary";"no";2...
# 3      47;"blue-collar";"married";"unknown";"no";1506...
# 4      33;"unknown";"single";"unknown";"no";1;"no";"n...
# ...                                                  ...
# 45206  51;"technician";"married";"tertiary";"no";825;...
# 45207  71;"retired";"divorced";"primary";"no";1729;"n...
# 45208  72;"retired";"married";"secondary";"no";5715;"...
# 45209  57;"blue-collar";"married";"secondary";"no";66...
# 45210  37;"entrepreneur";"married";"secondary";"no";2...
#
# [45211 rows x 1 columns]

# %%
    pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic= pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
titanic['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_num=titanic.select_dtypes(["int64","object"])

# %%
titanic_num
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
titanic_num=titanic.select_dtypes(["int64","float"])

# %%
titanic_num
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
titanic.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
titanic.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic_num.to_excel('titanic.xlsx',index= False)

# %%
titanic_num.to_html('titanic.html')

# %%
tail=titanic.tail(3)

# %%
tail.to_html('titanictail.html')

# %%
{'Class1': ['Arun','Amal','Sharoon'],'Class2':['Shaan',"Shinan","Resbin"],'class3':['hafshm','Aswnth','Shamil']}
# Out:
# {'Class1': ['Arun', 'Amal', 'Sharoon'],
#  'Class2': ['Shaan', 'Shinan', 'Resbin'],
#  'class3': ['hafshm', 'Aswnth', 'Shamil']}

# %%
testfile = {'Class1': ['Arun','Amal','Sharoon'],'Class2':['Shaan',"Shinan","Resbin"],'class3':['hafshm','Aswnth','Shamil']}

# %%
pd.DataFrame(testfile)
# Out:
#     Class1  Class2  class3
# 0     Arun   Shaan  hafshm
# 1     Amal  Shinan  Aswnth
# 2  Sharoon  Resbin  Shamil

# %%
testfile['Class1'][2]
# Out:
# 'Sharoon'
